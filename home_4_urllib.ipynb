# %%
import json
import urllib2
from lxml import html
url = "https://www.youtube.com/feed/trending"
response = urllib2.urlopen(url)
page = response.read()
tree = html.document_fromstring(page)
title_link = tree.cssselect('[class="yt-uix-tile-link yt-ui-ellipsis yt-ui-ellipsis-2 yt-uix-sessionlink      spf-link "] ')
duration=tree.cssselect('[class="video-time"]')
user=tree.cssselect('[class="g-hovercard yt-uix-sessionlink       spf-link "]')
data = tree.cssselect('[class="yt-lockup-meta-info"] ' ) 
zzz=[]
for i in data:
    for j in i:
        zzz.append(j.text)
lll=zzz[1::2]
data1=[]
for i,z,a,b in zip(title,duration,user,lll):
    data1.append({'Title ' :i.get("title"),"URL" : "https://www.youtube.com"+"i.get('href')",'Duration':z.text,"Username":a.text,"Views": b})
print(data1)

with open('trending_urllib.json', 'w') as output:
    json.dump(data1, output, sort_keys = True, indent = 4)


import unicodecsv as csv

with open('trending_urllib.csv', 'w') as csv_file:
    for i in data1:
            writer = csv.writer(csv_file)
            for z, x in i.items():
                writer.writerow([z, x])
            writer.writerow([])
# Out:
# [{'Title ': 'JUMANJI: WELCOME TO THE JUNGLE - Official Trailer (HD)', 'URL': "https://www.youtube.comi.get('href')", 'Username': 'Sony Pictures Entertainment', 'Duration': '2:46', 'Views': '2,974,978 views'}, {'Title ': 'Everything Wrong With Despicable Me 2 In 16 Minutes Or Less', 'URL': "https://www.youtube.comi.get('href')", 'Username': 'CinemaSins', 'Duration': '18:41', 'Views': '1,536,000 views'}, {'Title ': "Marvel's Inhumans - Official Trailer 1", 'URL': "https://www.youtube.comi.get('href')", 'Username': 'Marvel Entertainment', 'Duration': '1:57', 'Views': '3,438,491 views'}, {'Title ': 'Death Note | Official Trailer [HD] | Netflix', 'URL': "https://www.youtube.comi.get('href')", 'Username': 'Netflix', 'Duration': '2:18', 'Views': '1,076,018 views'}, {'Title ': "Trump Doesn't Seem to Know Anything About Health Care: A Closer Look", 'URL': "https://www.youtube.comi.get('href')", 'Username': 'Conagh Kathleen', 'Duration': '8:46', 'Views': '3 days ago'}, {'Title ': 'Breathe Offi
# ...

# %%
import json

with open('trending_urllib.json') as json_data:
    d = json.load(json_data)
    print(d)
# Out:
# [{u'Duration': u'2:46', u'Title ': u'JUMANJI: WELCOME TO THE JUNGLE - Official Trailer (HD)', u'Username': u'Sony Pictures Entertainment', u'URL': u"https://www.youtube.comi.get('href')", u'Views': u'2,974,978 views'}, {u'Duration': u'18:41', u'Title ': u'Everything Wrong With Despicable Me 2 In 16 Minutes Or Less', u'Username': u'CinemaSins', u'URL': u"https://www.youtube.comi.get('href')", u'Views': u'1,536,000 views'}, {u'Duration': u'1:57', u'Title ': u"Marvel's Inhumans - Official Trailer 1", u'Username': u'Marvel Entertainment', u'URL': u"https://www.youtube.comi.get('href')", u'Views': u'3,438,491 views'}, {u'Duration': u'2:18', u'Title ': u'Death Note | Official Trailer [HD] | Netflix', u'Username': u'Netflix', u'URL': u"https://www.youtube.comi.get('href')", u'Views': u'1,076,018 views'}, {u'Duration': u'8:46', u'Title ': u"Trump Doesn't Seem to Know Anything About Health Care: A Closer Look", u'Username': u'Conagh Kathleen', u'URL': u"https://www.youtube.comi.get('href')", 
# ...

# %%
from pprint import*

# %%
pprint(d)
# Out:
# [{u'Duration': u'2:46',
#   u'Title ': u'JUMANJI: WELCOME TO THE JUNGLE - Official Trailer (HD)',
#   u'URL': u"https://www.youtube.comi.get('href')",
#   u'Username': u'Sony Pictures Entertainment',
#   u'Views': u'2,974,978 views'},
#  {u'Duration': u'18:41',
#   u'Title ': u'Everything Wrong With Despicable Me 2 In 16 Minutes Or Less',
#   u'URL': u"https://www.youtube.comi.get('href')",
#   u'Username': u'CinemaSins',
#   u'Views': u'1,536,000 views'},
#  {u'Duration': u'1:57',
#   u'Title ': u"Marvel's Inhumans - Official Trailer 1",
#   u'URL': u"https://www.youtube.comi.get('href')",
#   u'Username': u'Marvel Entertainment',
#   u'Views': u'3,438,491 views'},
#  {u'Duration': u'2:18',
#   u'Title ': u'Death Note | Official Trailer [HD] | Netflix',
#   u'URL': u"https://www.youtube.comi.get('href')",
#   u'Username': u'Netflix',
#   u'Views': u'1,076,018 views'},
#  {u'Duration': u'8:46',
#   u'Title ': u"Trump Doesn't Seem to Know Anything About Health Care: A Closer Look",
# ...
