# %%
import json
import urllib2
from lxml import html
url = "https://www.youtube.com/feed/trending"
response = urllib2.urlopen(url)
page = response.read()
tree = html.document_fromstring(page)
title = tree.cssselect('[class="yt-uix-tile-link yt-ui-ellipsis yt-ui-ellipsis-2 yt-uix-sessionlink      spf-link "] ')
link= tree.cssselect('[class="yt-uix-tile-link yt-ui-ellipsis yt-ui-ellipsis-2 yt-uix-sessionlink      spf-link "]')
duration=tree.cssselect('[class="video-time"]')
user=tree.cssselect('[class="g-hovercard yt-uix-sessionlink       spf-link "]')
data = tree.cssselect('[class="yt-lockup-meta-info"] ' ) 
zzz=[]
for i in data:
    for j in i:
        zzz.append(j.text)
lll=zzz[1::2]
data1=[]
for i,j,z,a,b in zip(title,duration,link,user,lll):
    data1.append({'Title ' :i.get("title"),"URL" : "https://www.youtube.com"+"j.get('href')",'Duration':z.text,"Username":a.text,"Views": b})
print(data1)

with open('trending_urllib.json', 'w') as output:
    json.dump(data1, output, sort_keys = True, indent = 4)


import unicodecsv as csv

with open('trending_urllib.csv', 'w') as csv_file:
    for i in data1:
            writer = csv.writer(csv_file)
            for z, x in i.items():
                writer.writerow([z, x])
            writer.writerow([])
# Out:
# [{'Title ': 'JUMANJI: WELCOME TO THE JUNGLE - Official Trailer (HD)', 'URL': "https://www.youtube.comj.get('href')", 'Username': 'Sony Pictures Entertainment', 'Duration': 'JUMANJI: WELCOME TO THE JUNGLE - Official Trailer (HD)', 'Views': '2,974,978 views'}, {'Title ': 'Everything Wrong With Despicable Me 2 In 16 Minutes Or Less', 'URL': "https://www.youtube.comj.get('href')", 'Username': 'CinemaSins', 'Duration': 'Everything Wrong With Despicable Me 2 In 16 Minutes Or Less', 'Views': '1,536,000 views'}, {'Title ': "Marvel's Inhumans - Official Trailer 1", 'URL': "https://www.youtube.comj.get('href')", 'Username': 'Marvel Entertainment', 'Duration': "Marvel's Inhumans - Official Trailer 1", 'Views': '3,438,491 views'}, {'Title ': 'Death Note | Official Trailer [HD] | Netflix', 'URL': "https://www.youtube.comj.get('href')", 'Username': 'Netflix', 'Duration': 'Death Note | Official Trailer [HD] | Netflix', 'Views': '1,076,018 views'}, {'Title ': "Trump Doesn't Seem to Know Anything Abo
# ...

# %%
import json

with open('trending.json') as json_data:
    d = json.load(json_data)
    print(d)

# %%
from pprint import*

# %%
pprint(d)
# Out:
# [{u'Duration': u'3:55',
#   u'Title ': u'Van Jones: Russia is \u201cNothing burger\u201d\u2013 American Pravda: CNN Part 2',
#   u'URL': u'https://www.youtube.com/watch?v=l2G360HrSAs',
#   u'Username': u'veritasvisuals',
#   u'Views': u'1,130,532 views'},
#  {u'Duration': u'1:57',
#   u'Title ': u"Marvel's Inhumans - Official Trailer 1",
#   u'URL': u'https://www.youtube.com/watch?v=1sYF1SXcWqQ',
#   u'Username': u'Marvel Entertainment',
#   u'Views': u'572,570 views'},
#  {u'Duration': u'2:46',
#   u'Title ': u'JUMANJI: WELCOME TO THE JUNGLE - Official Trailer (HD)',
#   u'URL': u'https://www.youtube.com/watch?v=2QKg5SZ_35I',
#   u'Username': u'Sony Pictures Entertainment',
#   u'Views': u'219,624 views'},
#  {u'Duration': u'5:56',
#   u'Title ': u"Medicaid's Last Stand | June 28, 2017 Part 1 | Full Frontal on TBS",
#   u'URL': u'https://www.youtube.com/watch?v=0EzEMsZFrXY',
#   u'Username': u'Full Frontal with Samantha Bee',
#   u'Views': u'143,033 views'},
# ...
